# %%
import requests
from urllib3 import PoolManager

import pandas as pd

# %% [markdown]
# # TO REMEMBER
#
# drs = {
#     0: "Off",
#     1: "Off",
#     2: "(?)",
#     3: "(?)",
#     8: "Detected, Eligible once in Activation Zone",
#     9: "(?)",
#     10: "On",
#     12: "On",
#     14: "On",
# }

# %%
link = r"https://api.openf1.org/v1/"
types = ("car_data", "drivers", "intervals", "laps", "location", "meetings", "pit", "position", "race_control", "sessions", "stints", "team_radio", "weather")

session = requests.Session()

# %%
headers = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
api_data = requests.get(link+"car_data?driver_number=14&session_key=latest", headers=headers).json()

response = session.get(link+"car_data?driver_number=14&session_key=latest")
response = session.get(link+"car_data?driver_number=14&session_key=latest")

display(response.json())

# https://skillshats.com/blogs/optimize-python-requests-for-faster-performance/

# http = PoolManager()

# response = http.request('GET', 'http://example.com')
# Out:
# [{'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-21T14:19:02.042000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 104,
#   'drs': 8,
#   'brake': 104},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-21T14:19:02.242000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 104,
#   'drs': 8,
#   'brake': 104},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-21T14:19:02.402000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 104,
#   'drs': 8,
#   'brake': 104},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:06:58.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:06:58.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:06:59.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:06:59.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:06:59.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:00.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:00.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:00.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:01.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:01.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:01.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:01.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:01.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:02.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:02.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:02.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:03.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:03.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:03.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:03.691000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:03.971000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:04.131000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:04.291000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:04.531000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:04.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:05.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:05.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:05.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:05.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:06.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:06.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:06.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:07.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:07.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:07.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:08.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:08.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:08.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:08.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:09.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:09.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:09.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:10.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:10.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:10.411000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:10.651000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:10.971000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:11.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:11.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:11.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:12.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:12.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:12.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:13.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:13.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:13.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:13.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:13.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:14.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:14.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:14.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:14.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:15.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:15.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:16.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:16.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:16.372000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:16.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:16.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:17.091000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:17.331000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:17.491000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:17.691000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:17.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:18.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:18.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:18.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:19.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:19.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:19.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:19.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:20.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:20.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:20.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:20.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:21.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:21.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:21.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:21.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:22.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:22.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:22.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:23.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:23.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:23.851000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:24.091000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:24.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:24.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:25.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:25.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:25.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:25.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:25.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:26.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:26.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:26.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:26.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:27.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:27.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:27.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:27.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:27.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:28.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:28.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:28.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:28.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:29.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:29.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:29.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:30.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:30.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:30.731000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:31.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:31.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:31.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:31.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:32.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:32.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:32.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:32.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:33.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:33.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:33.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:33.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:34.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:34.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:34.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:34.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:34.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:35.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:35.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:35.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:36.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:36.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:36.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:36.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:36.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:37.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:37.491000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:37.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:38.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:38.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:38.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:39.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:39.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:39.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:40.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:40.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:40.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:40.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:41.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:41.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:41.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:41.972000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:42.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:42.372000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:42.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:42.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:43.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:43.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:43.931000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:44.212000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:44.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:44.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:45.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:45.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:45.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:45.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:46.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:46.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:46.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:47.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:47.372000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:47.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:47.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:48.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:48.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:48.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:49.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:49.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:49.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:49.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:50.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:50.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:50.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:51.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:51.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:51.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:51.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:52.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:52.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:52.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:52.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:53.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:53.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:53.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:53.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:54.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:54.372000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:54.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:54.772000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:55.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:55.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:55.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:55.932000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:56.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:56.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:56.612000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:56.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:57.253000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:57.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:57.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:58.052000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:58.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:58.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:58.652000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:58.812000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:59.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:07:59.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:00.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:00.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:00.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:00.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:00.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:01.252000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:01.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:08:01.732000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
# ...
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:01.332000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:01.613000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:02.013000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:02.373000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:02.813000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:03.013000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:03.213000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:03.613000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:03.893000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:04.173000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:04.453000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:04.693000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:04.933000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:05.133000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:05.333000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:05.613000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:05.853000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:06.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:06.372000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:06.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:06.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:07.172000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:07.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:07.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:08.133000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:08.373000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:08.533000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:08.773000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:09.173000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:09.413000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:09.653000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:09.893000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:10.133000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:10.333000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:10.613000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:10.813000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:10.973000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:11.453000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:11.613000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:11.853000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:12.173000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:12.453000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:12.892000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:13.092000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:13.292000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:13.492000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:13.692000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:13.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:14.132000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:14.412000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:14.572000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:14.733000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:14.973000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:15.333000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:15.493000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:15.733000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:15.893000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:16.293000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:16.493000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:16.733000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:16.893000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:17.133000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:17.493000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:17.733000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:18.093000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:18.293000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:18.493000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:18.773000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:19.213000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:19.532000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:19.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:20.012000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:20.452000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:20.852000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:21.213000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:21.373000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:21.573000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:21.773000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:22.053000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  {'meeting_key': 1246,
#   'session_key': 9606,
#   'driver_number': 14,
#   'date': '2024-09-22T11:11:22.493000+00:00',
#   'rpm': 0,
#   'speed': 0,
#   'n_gear': 0,
#   'throttle': 0,
#   'drs': 0,
#   'brake': 0},
#  ...]

# %%
df = pd.json_normalize(api_data)
df
# Out:
#        meeting_key  session_key  driver_number  \
# 0             1246         9606             14
# 1             1246         9606             14
# 2             1246         9606             14
# 3             1246         9606             14
# 4             1246         9606             14
# ...            ...          ...            ...
# 36323         1246         9606             14
# 36324         1246         9606             14
# 36325         1246         9606             14
# 36326         1246         9606             14
# 36327         1246         9606             14
#
#                                    date   rpm  speed  n_gear  throttle  drs  \
# 0      2024-09-21T14:19:02.042000+00:00     0      0       0       104    8
# 1      2024-09-21T14:19:02.242000+00:00     0      0       0       104    8
# 2      2024-09-21T14:19:02.402000+00:00     0      0       0       104    8
# 3      2024-09-22T11:06:58.452000+00:00     0      0       0         0    0
# 4      2024-09-22T11:06:58.852000+00:00     0      0       0         0    0
# ...                                 ...   ...    ...     ...       ...  ...
# 36323  2024-09-22T13:47:25.405000+00:00  4628     55       2         0    0
# 36324  2024-09-22T13:47:25.605000+00:00  4523     54       2         0    0
# 36325  2024-09-22T13:47:25.885000+00:00  4520     53       2         2    0
# 36326  2024-09-22T13:47:26.165000+00:00  4794     54       2        10    0
# 36327  2024-09-22T13:47:26.365000+00:00  4954     55       2        12    0
#
#        brake
# 0        104
# 1        104
# 2        104
# 3          0
# 4          0
# ...      ...
# 36323      0
# 36324      0
# 36325      0
# 36326      0
# 36327      0
#
# [36328 rows x 10 columns]
