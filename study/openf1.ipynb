# %% [markdown]
# # Open F1 API
#
# Open F1 unfortunately does not give full details on telemetry, required to do a full depth analysis

# %%
import requests
from urllib3 import PoolManager

import pandas as pd

# %% [markdown]
# # TO REMEMBER
#
# drs = {
#     0: "Off",
#     1: "Off",
#     2: "(?)",
#     3: "(?)",
#     8: "Detected, Eligible once in Activation Zone",
#     9: "(?)",
#     10: "On",
#     12: "On",
#     14: "On",
# }

# %%
link = r"https://api.openf1.org/v1/"
types = ("car_data", "drivers", "intervals", "laps", "location", "meetings", "pit", "position", "race_control", "sessions", "stints", "team_radio", "weather")

session = requests.Session()

# %%
# headers = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

api_data = requests.get(link+"laps?driver_number=55&session_key=latest&lap_number=2").json()
df = pd.json_normalize(api_data)

# https://skillshats.com/blogs/optimize-python-requests-for-faster-performance/

# http = PoolManager()

# response = http.request('GET', 'http://example.com')

# %%
df
# Out:
#    meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0         1252         9662             55       279       182       294
#
#                          date_start  lap_duration  is_pit_out_lap  \
# 0  2024-12-08T13:05:08.545000+00:00        109.77           False
#
#    duration_sector_1  duration_sector_2  duration_sector_3  \
# 0             18.329             45.655             45.786
#
#                 segments_sector_1  \
# 0  [2049, 2049, 2049, 2049, 2048]
#
#                                    segments_sector_2  \
# 0  [2048, 2049, 2048, 2048, 2049, 2049, 2048, 204...
#
#                                    segments_sector_3  lap_number
# 0  [2049, 2049, 2049, 2051, 2051, 2051, 2051, 205...           2
